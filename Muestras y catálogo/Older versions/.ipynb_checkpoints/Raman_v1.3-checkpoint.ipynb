# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image as img
from PIL import ImageDraw,ImageFont
from raman_analyzer import *

# %%
# Ejemplo
global_path = './Muestras_12-11-24'
# IO crea las carpetas necesarias
IO(global_path)
name = 'Primeras muestras'
date = '12-11-24'
# Conjunto de datos analizados
batch = Batch(name, date=date)

# %%
# batch.generate_catalog_entries()
# batch.anex_to_catalog()

# %%
# Seleccionar una de las muestras
weird_one = batch['Muestra 3']['zona1']
weird_one.show_img()
print(weird_one.graph_names)
for fig in weird_one.figs:
    IO.show_fig(fig)
# Out:
# zona1
# ['Muestra 3_100x_zona1_rojo.png', 'Muestra 3_20x_zona1_rojo.png']

# %%
# Seleccionar toda una muestra
muestra1 = batch['Muestra 1']
for zone_name in muestra1.zones:
    muestra1[zone_name].show_img()
# Out:
# zona1
# zona2
# zona3
